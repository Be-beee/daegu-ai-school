# %%
import glob
import os
import torchvision.transforms as transforms
import torchvision
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
import cv2
import torch

from torchvision import datasets, models, transforms
from PIL import Image
from torch.utils.data import Dataset, DataLoader

# %%
# torch version gpu 사용 유무 체크
print("torch version >>", torch.__version__)
print("GPU Available >> ", torch.cuda.is_available())
# Out:
# torch version >> 1.9.0+cu102
# GPU Available >>  True

# %%
# device 설정 GPU 사용 가능 여부에 따라 device 정보 저장
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# data check function
# output_dir = "./content/drive/MyDrive/classification/cat_dog_data"


def dataset_check(output_dir):
  try:
    # output_dir
    # train data check
    all_train_cat = glob.glob(os.path.join(output_dir, "train", "cat", "*.jpg"))
    all_train_dog = glob.glob(os.path.join(output_dir, "train", "dog", "*.jpg"))

    # val data check
    all_val_cat = glob.glob(os.path.join(output_dir, "val", "cat", "*.jpg"))
    all_val_dog = glob.glob(os.path.join(output_dir, "val", "dog", "*.jpg"))


    # test data check
    all_test_cat = glob.glob(os.path.join(output_dir, "test", "cat", "*.jpg"))
    all_test_dog = glob.glob(os.path.join(output_dir, "test", "dog", "*.jpg"))

    # print
    print("train cat image number >> ", len(all_train_cat))
    print("train cat image number >> ", len(all_train_dog))

    print("train cat image number >> ", len(all_val_cat))
    print("train cat image number >> ", len(all_val_dog))

    print("train cat image number >> ", len(all_test_cat))
    print("train cat image number >> ", len(all_test_dog))

  except Exception as e:
    print("check error 코드 구현을 완료했는지 검토하십시요~")
    print(e)


# data location
data_dir = "/content/drive/MyDrive/classification/cat_dog_data"
# data_dir = "/content/cat_dog_data"

# data check
dataset_check(data_dir)
# Out:
# train cat image number >>  1000
# train cat image number >>  1000
# train cat image number >>  500
# train cat image number >>  500
# train cat image number >>  1000
# train cat image number >>  1000

# %%
# hyper parameter setting

batch_size = 32
num_epochs = 40
learning_rate = 0.01

# %%
class catdogDataset(Dataset):
  def __init__(self, data_dir, mode, transform=None):
    # 데이터 정의
    # data_dir/train/cat/images
    self.all_data = sorted(glob.glob(os.path.join(data_dir, mode, "*", "*")))
    self.transform = transform

  def __getitem__(self, item):
    # 데이터 이미지 읽기
    data_path = self.all_data[item]
    img = Image.open(data_path)
    img = img.convert("RGB")

    # label 읽기
    label_name = os.path.basename(data_path)
    label_str = str(label_name)

    if label_str.startswith("cat") == True:
      label = 0
    else:
      label = 1

    # transform is not None
    if self.transform is not None:
      img = self.transform(img)

    return img, label


  def __len__(self):
    length = len(self.all_data)

    return length

# %%
from torchvision.transforms.functional import normalize
# data transforms
# image resize -> 224 224
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomRotation(5),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.Resize([224, 224]),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize([224, 224]),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize([224, 224]),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# %%
# data 정의 및 dataloader 코드 구현
# dataset (train, val, test)
train_data_set = catdogDataset(data_dir="/content/drive/MyDrive/classification/cat_dog_data", mode="train", transform=data_transforms["train"])
val_data_set = catdogDataset(data_dir="/content/drive/MyDrive/classification/cat_dog_data", mode="val", transform=data_transforms["val"])
test_data_set = catdogDataset(data_dir="/content/drive/MyDrive/classification/cat_dog_data", mode="test", transform=data_transforms["test"])


# data loader
train_loader = DataLoader(train_data_set, batch_size=batch_size, shuffle=True, drop_last=True)
val_loader = DataLoader(val_data_set, batch_size=batch_size, shuffle=False, drop_last=True)
test_loader = DataLoader(test_data_set, batch_size=batch_size, shuffle=False, drop_last=True)

# %%
# 간단한 모델 구성

class SimpleCNN(nn.Module):
  def __init__(self):
    super(SimpleCNN, self).__init__()

    #self conv 구현
    self.conv = nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3),
        nn.BatchNorm2d(32),
        nn.ReLU(),
        nn.MaxPool2d(2),

        nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),
        nn.BatchNorm2d(64),
        nn.ReLU(),
        nn.MaxPool2d(2),

        nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3),
        nn.BatchNorm2d(128),
        nn.ReLU(),
        nn.MaxPool2d(2),

        nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3),
        nn.BatchNorm2d(128),
        nn.ReLU(),
        nn.MaxPool2d(2),

        nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3),
        nn.BatchNorm2d(256),
        nn.ReLU(),
        nn.MaxPool2d(2),
    )


    # fc1, fc2

    self.fc1 = nn.Linear(256 * 5 * 5, 512)
    self.fc2 = nn.Linear(512, 2)

  def forward(self, x):
    x = self.conv(x)
    x = x.view(x.shape[0], -1)
    x = F.relu(self.fc1(x))
    x = self.fc2(x)

    return x

# %%
net = SimpleCNN().to(device)
# print(net)

# vgg16 사용시
# net = models.vgg16(pretrained=True).to(device)
# net.classifier[6] = nn.Linear(4096, 2)

# resnet18 사용시
# net = models.resnet18(pretrained=True).to(device)
# num_ftrs = net.fc.in_features
# net.fc = nn.Linear(num_ftrs, 2)


model = net.to(device)

# %%
# loss function, optimizer scheduler
criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.1)

# %%
def train(num_epochs, model, data_loader, criterion, optimizer, save_dir, val_every, device):
  print("Start Training")
  best_loss = 9999


  for epoch in range(num_epochs):
    for i, (imgs, labels) in enumerate(data_loader):
      images, labels = imgs.to(device), labels.to(device)

      outputs = net(images)

      loss = criterion(outputs, labels)

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      _,  argmax = torch.max(outputs, 1)
      accuracy = (labels == argmax).float().mean()

      if (i + 1) % 3 == 0:
        print("epoch [{}/{}], step [{}/{}], loss: {:.4f}, Accuracy: {:.2f}%"
        .format(epoch + 1, num_epochs, i+1, len(train_loader), loss.item(), accuracy.item() * 100))

    if (epoch + 1) % val_every == 0:
      avrg_loss = validation(epoch+1, model, val_loader, criterion, device)

      if avrg_loss < best_loss:
        print("Best Performace at epoch: {}".format(epoch+1))
        print("save model in", save_dir)
        best_loss = avrg_loss
        save_model(model, save_dir)

# %%
def validation(epoch, model, data_loader, criterion, device):
  print("Start val")
  model.eval()

  with torch.no_grad():
    total = 0
    correct = 0
    total_loss = 0
    cnt = 0

    for i, (imgs, labels) in enumerate(data_loader):
      images, labels = imgs.to(device), labels.to(device)
      output = net(images)

      loss = criterion(output, labels)

      total += imgs.size(0)
      _, argmax = torch.max(output, 1)
      accuracy = (labels == argmax).float().mean()

      correct += (labels == argmax).sum().item()
      total_loss += loss
      cnt += 1


    avrg_loss = total_loss/cnt
    print("Validation #{} Accuracy {:.2f} % Average Loss: {:.4f}".format(epoch, correct/total * 100, avrg_loss))

  model.train()

  return avrg_loss

# %%
# save model

def save_model(model, save_dir, file_name="best_model_simple_cnn.pth"):
  os.makedirs(save_dir, exist_ok=True)
  output_path = os.path.join(save_dir, file_name)
  torch.save(net.state_dict(), output_path)

# %%
# test

def test(model, data_loader, device):
  print("Start test")

  correct = 0
  total = 0
  with torch.no_grad():

    for i, (img, labels) in enumerate(data_loader):
      imgs, labels = imgs.to(device), labels.to(device)

      outputs = net(img)
      _, argmax = torch.max(outputs, 1)
      total += imgs.size(0)
      correct += (labels == argmax).sum().item()

    print("Test Accuracy for {} images: {:.2f}%".format(total, correct / total * 100))

# %%
# model = net
val_every = 1
save_dir = "/content/drive/MyDrive/classification/weights/"

train(num_epochs, model, train_loader, criterion, optimizer, save_dir, val_every, device)
# Out:
# Start Training
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# epoch [1/40], step [3/62], loss: 0.7386, Accuracy: 40.62%
# epoch [1/40], step [6/62], loss: 0.5984, Accuracy: 65.62%
# epoch [1/40], step [9/62], loss: 0.8684, Accuracy: 53.12%
# epoch [1/40], step [12/62], loss: 0.7242, Accuracy: 59.38%
# epoch [1/40], step [15/62], loss: 0.6338, Accuracy: 59.38%
# epoch [1/40], step [18/62], loss: 0.6558, Accuracy: 59.38%
# epoch [1/40], step [21/62], loss: 0.6825, Accuracy: 59.38%
# epoch [1/40], step [24/62], loss: 0.6391, Accuracy: 71.88%
# epoch [1/40], step [27/62], loss: 0.6631, Accuracy: 62.50%
# epoch [1/40], step [30/62], loss: 0.6419, Accuracy: 59.38%
# epoch [1/40], step [33/62], loss: 0.6238, Accuracy: 65.62%
# epoch [1/40], step [36/62], loss: 0.6330, Accuracy: 62.50%
# epoch [1/40], step [39/62], loss: 0.5625, Accuracy: 78.12%
# epoch [1/40], step [42/62], loss: 0.6246, Accuracy: 65.62%
# epoch [1/40], step [45/62], loss: 0.7116, Accuracy: 56.25%
# epoch [1/40], step [48/62], loss: 0.6131, Accuracy: 75.00%
# epoch [1/40], step [51/62], loss: 0.6804, Accuracy: 56.25%
# epoch [1/40], step [54/62], loss: 0.5862, Accuracy: 71.88%
# epoch [1/40], step [57/62], loss: 0.5610, Accuracy: 68.75%
# epoch [1/40], step [60/62], loss: 0.7043, Accuracy: 62.50%
# Start val
# Validation #1 Accuracy 63.61 % Average Loss: 0.6760
# Best Performace at epoch: 1
# save model in /content/drive/MyDrive/classification/weights/
# epoch [2/40], step [3/62], loss: 0.8516, Accuracy: 53.12%
# epoch [2/40], step [6/62], loss: 0.6025, Accuracy: 65.62%
# epoch [2/40], step [9/62], loss: 0.6235, Accuracy: 68.75%
# epoch [2/40], step [12/62], loss: 0.5300, Accuracy: 78.12%
# epoch [2/40], step [15/62], loss: 0.7163, Accuracy: 59.38%
# epoch [2/40], step [18/62], loss: 0.4142, Accuracy: 81.25%
# epoch [2/40], step [21/62], loss: 0.5145, Accuracy: 75.00%
# epoch [2/40], step [24/62], loss: 0.7162, Accuracy: 62.50%
# epoch [2/40], step [27/62], loss: 0.5530, Accuracy: 71.88%
# epoch [2/40], step [30/62], loss: 0.6579, Accuracy: 53.12%
# epoch [2/40], step [33/62], loss: 0.6826, Accuracy: 68.75%
# epoch [2/40], step [36/62], loss: 0.5951, Accuracy: 62.50%
# epoch [2/40], step [39/62], loss: 0.5914, Accuracy: 65.62%
# epoch [2/40], step [42/62], loss: 0.6348, Accuracy: 71.88%
# epoch [2/40], step [45/62], loss: 0.6750, Accuracy: 59.38%
# epoch [2/40], step [48/62], loss: 0.6608, Accuracy: 68.75%
# epoch [2/40], step [51/62], loss: 0.5397, Accuracy: 71.88%
# epoch [2/40], step [54/62], loss: 0.5709, Accuracy: 68.75%
# epoch [2/40], step [57/62], loss: 0.5466, Accuracy: 71.88%
# epoch [2/40], step [60/62], loss: 0.5575, Accuracy: 65.62%
# Start val
# Validation #2 Accuracy 69.96 % Average Loss: 0.5745
# Best Performace at epoch: 2
# save model in /content/drive/MyDrive/classification/weights/
# epoch [3/40], step [3/62], loss: 0.4911, Accuracy: 75.00%
# epoch [3/40], step [6/62], loss: 0.5289, Accuracy: 75.00%
# epoch [3/40], step [9/62], loss: 0.6969, Accuracy: 59.38%
# epoch [3/40], step [12/62], loss: 0.5255, Accuracy: 71.88%
# epoch [3/40], step [15/62], loss: 0.5689, Accuracy: 68.75%
# epoch [3/40], step [18/62], loss: 0.6626, Accuracy: 62.50%
# epoch [3/40], step [21/62], loss: 0.3631, Accuracy: 90.62%
# epoch [3/40], step [24/62], loss: 0.6067, Accuracy: 65.62%
# epoch [3/40], step [27/62], loss: 0.5192, Accuracy: 75.00%
# epoch [3/40], step [30/62], loss: 0.6739, Accuracy: 71.88%
# epoch [3/40], step [33/62], loss: 0.5511, Accuracy: 71.88%
# epoch [3/40], step [36/62], loss: 0.6182, Accuracy: 71.88%
# epoch [3/40], step [39/62], loss: 0.6152, Accuracy: 65.62%
# epoch [3/40], step [42/62], loss: 0.4878, Accuracy: 78.12%
# epoch [3/40], step [45/62], loss: 0.6029, Accuracy: 68.75%
# epoch [3/40], step [48/62], loss: 0.5061, Accuracy: 75.00%
# epoch [3/40], step [51/62], loss: 0.4633, Accuracy: 75.00%
# epoch [3/40], step [54/62], loss: 0.5813, Accuracy: 68.75%
# epoch [3/40], step [57/62], loss: 0.4876, Accuracy: 81.25%
# epoch [3/40], step [60/62], loss: 0.6068, Accuracy: 53.12%
# Start val
# Validation #3 Accuracy 57.86 % Average Loss: 0.6888
# epoch [4/40], step [3/62], loss: 0.5111, Accuracy: 71.88%
# epoch [4/40], step [6/62], loss: 0.5922, Accuracy: 68.75%
# epoch [4/40], step [9/62], loss: 0.5918, Accuracy: 65.62%
# epoch [4/40], step [12/62], loss: 0.5138, Accuracy: 71.88%
# epoch [4/40], step [15/62], loss: 0.3931, Accuracy: 78.12%
# epoch [4/40], step [18/62], loss: 0.7206, Accuracy: 59.38%
# epoch [4/40], step [21/62], loss: 0.4864, Accuracy: 71.88%
# epoch [4/40], step [24/62], loss: 0.5639, Accuracy: 68.75%
# epoch [4/40], step [27/62], loss: 0.5993, Accuracy: 71.88%
# epoch [4/40], step [30/62], loss: 0.7423, Accuracy: 56.25%
# epoch [4/40], step [33/62], loss: 0.5628, Accuracy: 65.62%
# epoch [4/40], step [36/62], loss: 0.7331, Accuracy: 53.12%
# epoch [4/40], step [39/62], loss: 0.5417, Accuracy: 68.75%
# epoch [4/40], step [42/62], loss: 0.4905, Accuracy: 68.75%
# epoch [4/40], step [45/62], loss: 0.4704, Accuracy: 78.12%
# epoch [4/40], step [48/62], loss: 0.4846, Accuracy: 75.00%
# epoch [4/40], step [51/62], loss: 0.5720, Accuracy: 71.88%
# epoch [4/40], step [54/62], loss: 0.5301, Accuracy: 68.75%
# epoch [4/40], step [57/62], loss: 0.5255, Accuracy: 68.75%
# epoch [4/40], step [60/62], loss: 0.5788, Accuracy: 75.00%
# Start val
# Validation #4 Accuracy 69.05 % Average Loss: 0.5857
# epoch [5/40], step [3/62], loss: 0.5451, Accuracy: 78.12%
# epoch [5/40], step [6/62], loss: 0.5536, Accuracy: 62.50%
# epoch [5/40], step [9/62], loss: 0.5223, Accuracy: 71.88%
# epoch [5/40], step [12/62], loss: 0.5842, Accuracy: 75.00%
# epoch [5/40], step [15/62], loss: 0.7573, Accuracy: 62.50%
# epoch [5/40], step [18/62], loss: 0.8188, Accuracy: 56.25%
# epoch [5/40], step [21/62], loss: 0.5701, Accuracy: 65.62%
# epoch [5/40], step [24/62], loss: 0.5756, Accuracy: 71.88%
# epoch [5/40], step [27/62], loss: 0.5578, Accuracy: 71.88%
# epoch [5/40], step [30/62], loss: 0.5714, Accuracy: 65.62%
# epoch [5/40], step [33/62], loss: 0.5549, Accuracy: 75.00%
# epoch [5/40], step [36/62], loss: 0.5157, Accuracy: 78.12%
# epoch [5/40], step [39/62], loss: 0.6087, Accuracy: 71.88%
# epoch [5/40], step [42/62], loss: 0.6393, Accuracy: 65.62%
# epoch [5/40], step [45/62], loss: 0.5412, Accuracy: 65.62%
# epoch [5/40], step [48/62], loss: 0.6785, Accuracy: 68.75%
# epoch [5/40], step [51/62], loss: 0.4657, Accuracy: 78.12%
# epoch [5/40], step [54/62], loss: 0.5214, Accuracy: 81.25%
# epoch [5/40], step [57/62], loss: 0.4472, Accuracy: 78.12%
# epoch [5/40], step [60/62], loss: 0.5607, Accuracy: 71.88%
# Start val
# Validation #5 Accuracy 71.57 % Average Loss: 0.5429
# Best Performace at epoch: 5
# save model in /content/drive/MyDrive/classification/weights/
# epoch [6/40], step [3/62], loss: 0.5115, Accuracy: 81.25%
# epoch [6/40], step [6/62], loss: 0.5803, Accuracy: 68.75%
# epoch [6/40], step [9/62], loss: 0.5449, Accuracy: 68.75%
# epoch [6/40], step [12/62], loss: 0.4968, Accuracy: 75.00%
# epoch [6/40], step [15/62], loss: 0.4482, Accuracy: 84.38%
# epoch [6/40], step [18/62], loss: 0.4468, Accuracy: 71.88%
# epoch [6/40], step [21/62], loss: 0.7180, Accuracy: 56.25%
# epoch [6/40], step [24/62], loss: 0.4839, Accuracy: 65.62%
# epoch [6/40], step [27/62], loss: 0.6493, Accuracy: 56.25%
# epoch [6/40], step [30/62], loss: 0.7249, Accuracy: 56.25%
# epoch [6/40], step [33/62], loss: 0.4798, Accuracy: 78.12%
# epoch [6/40], step [36/62], loss: 0.6161, Accuracy: 71.88%
# epoch [6/40], step [39/62], loss: 0.3947, Accuracy: 81.25%
# epoch [6/40], step [42/62], loss: 0.6046, Accuracy: 78.12%
# epoch [6/40], step [45/62], loss: 0.6159, Accuracy: 59.38%
# epoch [6/40], step [48/62], loss: 0.5656, Accuracy: 65.62%
# epoch [6/40], step [51/62], loss: 0.5722, Accuracy: 75.00%
# epoch [6/40], step [54/62], loss: 0.5375, Accuracy: 71.88%
# epoch [6/40], step [57/62], loss: 0.4630, Accuracy: 68.75%
# epoch [6/40], step [60/62], loss: 0.5965, Accuracy: 62.50%
# Start val
# Validation #6 Accuracy 61.39 % Average Loss: 0.6997
# epoch [7/40], step [3/62], loss: 0.5845, Accuracy: 68.75%
# epoch [7/40], step [6/62], loss: 0.4563, Accuracy: 81.25%
# epoch [7/40], step [9/62], loss: 0.6091, Accuracy: 68.75%
# epoch [7/40], step [12/62], loss: 0.5059, Accuracy: 71.88%
# epoch [7/40], step [15/62], loss: 0.5897, Accuracy: 68.75%
# epoch [7/40], step [18/62], loss: 0.3893, Accuracy: 87.50%
# epoch [7/40], step [21/62], loss: 0.4433, Accuracy: 78.12%
# epoch [7/40], step [24/62], loss: 0.5143, Accuracy: 81.25%
# epoch [7/40], step [27/62], loss: 0.6403, Accuracy: 65.62%
# epoch [7/40], step [30/62], loss: 0.9313, Accuracy: 56.25%
# epoch [7/40], step [33/62], loss: 0.6214, Accuracy: 71.88%
# epoch [7/40], step [36/62], loss: 0.4886, Accuracy: 71.88%
# epoch [7/40], step [39/62], loss: 0.5487, Accuracy: 71.88%
# epoch [7/40], step [42/62], loss: 0.5660, Accuracy: 59.38%
# epoch [7/40], step [45/62], loss: 0.6003, Accuracy: 68.75%
# epoch [7/40], step [48/62], loss: 0.6253, Accuracy: 59.38%
# epoch [7/40], step [51/62], loss: 0.4513, Accuracy: 81.25%
# epoch [7/40], step [54/62], loss: 0.4752, Accuracy: 71.88%
# epoch [7/40], step [57/62], loss: 0.4704, Accuracy: 78.12%
# epoch [7/40], step [60/62], loss: 0.4359, Accuracy: 81.25%
# Start val
# Validation #7 Accuracy 67.84 % Average Loss: 0.6980
# epoch [8/40], step [3/62], loss: 0.6661, Accuracy: 71.88%
# epoch [8/40], step [6/62], loss: 0.5570, Accuracy: 71.88%
# epoch [8/40], step [9/62], loss: 0.5725, Accuracy: 68.75%
# epoch [8/40], step [12/62], loss: 0.6228, Accuracy: 62.50%
# epoch [8/40], step [15/62], loss: 0.5153, Accuracy: 81.25%
# epoch [8/40], step [18/62], loss: 0.4755, Accuracy: 78.12%
# epoch [8/40], step [21/62], loss: 0.5178, Accuracy: 68.75%
# epoch [8/40], step [24/62], loss: 0.6565, Accuracy: 65.62%
# epoch [8/40], step [27/62], loss: 0.5335, Accuracy: 71.88%
# epoch [8/40], step [30/62], loss: 0.5219, Accuracy: 84.38%
# epoch [8/40], step [33/62], loss: 0.5895, Accuracy: 71.88%
# epoch [8/40], step [36/62], loss: 0.5159, Accuracy: 78.12%
# epoch [8/40], step [39/62], loss: 0.4523, Accuracy: 93.75%
# epoch [8/40], step [42/62], loss: 0.5724, Accuracy: 68.75%
# epoch [8/40], step [45/62], loss: 0.5046, Accuracy: 78.12%
# epoch [8/40], step [48/62], loss: 0.4433, Accuracy: 81.25%
# epoch [8/40], step [51/62], loss: 0.5567, Accuracy: 62.50%
# epoch [8/40], step [54/62], loss: 0.6814, Accuracy: 62.50%
# epoch [8/40], step [57/62], loss: 0.4612, Accuracy: 78.12%
# epoch [8/40], step [60/62], loss: 0.4685, Accuracy: 78.12%
# Start val
# Validation #8 Accuracy 73.49 % Average Loss: 0.5327
# Best Performace at epoch: 8
# save model in /content/drive/MyDrive/classification/weights/
# epoch [9/40], step [3/62], loss: 0.5152, Accuracy: 65.62%
# epoch [9/40], step [6/62], loss: 0.6080, Accuracy: 78.12%
# epoch [9/40], step [9/62], loss: 0.5828, Accuracy: 71.88%
# epoch [9/40], step [12/62], loss: 0.4495, Accuracy: 84.38%
# epoch [9/40], step [15/62], loss: 0.5640, Accuracy: 65.62%
# epoch [9/40], step [18/62], loss: 0.4662, Accuracy: 78.12%
# epoch [9/40], step [21/62], loss: 0.5438, Accuracy: 75.00%
# epoch [9/40], step [24/62], loss: 0.5510, Accuracy: 62.50%
# epoch [9/40], step [27/62], loss: 0.4149, Accuracy: 84.38%
# epoch [9/40], step [30/62], loss: 0.4467, Accuracy: 78.12%
# epoch [9/40], step [33/62], loss: 0.5409, Accuracy: 62.50%
# epoch [9/40], step [36/62], loss: 0.4957, Accuracy: 78.12%
# epoch [9/40], step [39/62], loss: 0.5601, Accuracy: 68.75%
# epoch [9/40], step [42/62], loss: 0.6659, Accuracy: 71.88%
# epoch [9/40], step [45/62], loss: 0.5402, Accuracy: 75.00%
# epoch [9/40], step [48/62], loss: 0.5680, Accuracy: 62.50%
# epoch [9/40], step [51/62], loss: 0.4967, Accuracy: 81.25%
# epoch [9/40], step [54/62], loss: 0.6487, Accuracy: 78.12%
# epoch [9/40], step [57/62], loss: 0.3949, Accuracy: 81.25%
# epoch [9/40], step [60/62], loss: 0.6132, Accuracy: 71.88%
# Start val
# Validation #9 Accuracy 68.95 % Average Loss: 0.5727
# epoch [10/40], step [3/62], loss: 0.5485, Accuracy: 68.75%
# epoch [10/40], step [6/62], loss: 0.4760, Accuracy: 78.12%
# epoch [10/40], step [9/62], loss: 0.4106, Accuracy: 78.12%
# epoch [10/40], step [12/62], loss: 0.3979, Accuracy: 78.12%
# epoch [10/40], step [15/62], loss: 0.6599, Accuracy: 68.75%
# epoch [10/40], step [18/62], loss: 0.6526, Accuracy: 71.88%
# epoch [10/40], step [21/62], loss: 0.4540, Accuracy: 75.00%
# epoch [10/40], step [24/62], loss: 0.6173, Accuracy: 68.75%
# epoch [10/40], step [27/62], loss: 0.4219, Accuracy: 81.25%
# epoch [10/40], step [30/62], loss: 0.4684, Accuracy: 75.00%
# epoch [10/40], step [33/62], loss: 0.6374, Accuracy: 68.75%
# epoch [10/40], step [36/62], loss: 0.5039, Accuracy: 78.12%
# epoch [10/40], step [39/62], loss: 0.5035, Accuracy: 68.75%
# epoch [10/40], step [42/62], loss: 0.5274, Accuracy: 78.12%
# epoch [10/40], step [45/62], loss: 0.3792, Accuracy: 81.25%
# epoch [10/40], step [48/62], loss: 0.4528, Accuracy: 78.12%
# epoch [10/40], step [51/62], loss: 0.9172, Accuracy: 53.12%
# epoch [10/40], step [54/62], loss: 0.5834, Accuracy: 78.12%
# epoch [10/40], step [57/62], loss: 0.4051, Accuracy: 87.50%
# epoch [10/40], step [60/62], loss: 0.4614, Accuracy: 78.12%
# Start val
# Validation #10 Accuracy 61.49 % Average Loss: 0.8947
# epoch [11/40], step [3/62], loss: 0.4273, Accuracy: 75.00%
# epoch [11/40], step [6/62], loss: 0.4503, Accuracy: 78.12%
# epoch [11/40], step [9/62], loss: 0.7081, Accuracy: 65.62%
# epoch [11/40], step [12/62], loss: 0.5038, Accuracy: 71.88%
# epoch [11/40], step [15/62], loss: 0.5593, Accuracy: 68.75%
# epoch [11/40], step [18/62], loss: 0.5152, Accuracy: 65.62%
# epoch [11/40], step [21/62], loss: 0.4107, Accuracy: 78.12%
# epoch [11/40], step [24/62], loss: 0.4962, Accuracy: 75.00%
# epoch [11/40], step [27/62], loss: 0.4758, Accuracy: 78.12%
# epoch [11/40], step [30/62], loss: 0.6322, Accuracy: 68.75%
# epoch [11/40], step [33/62], loss: 0.4329, Accuracy: 71.88%
# epoch [11/40], step [36/62], loss: 0.4731, Accuracy: 84.38%
# epoch [11/40], step [39/62], loss: 0.4847, Accuracy: 71.88%
# epoch [11/40], step [42/62], loss: 0.3644, Accuracy: 84.38%
# epoch [11/40], step [45/62], loss: 0.5768, Accuracy: 78.12%
# epoch [11/40], step [48/62], loss: 0.4773, Accuracy: 75.00%
# epoch [11/40], step [51/62], loss: 0.6911, Accuracy: 59.38%
# epoch [11/40], step [54/62], loss: 0.6951, Accuracy: 65.62%
# epoch [11/40], step [57/62], loss: 0.3289, Accuracy: 84.38%
# epoch [11/40], step [60/62], loss: 0.4283, Accuracy: 84.38%
# Start val
# Validation #11 Accuracy 72.78 % Average Loss: 0.5549
# epoch [12/40], step [3/62], loss: 0.3262, Accuracy: 81.25%
# epoch [12/40], step [6/62], loss: 0.4000, Accuracy: 84.38%
# epoch [12/40], step [9/62], loss: 0.2675, Accuracy: 84.38%
# epoch [12/40], step [12/62], loss: 0.4018, Accuracy: 81.25%
# epoch [12/40], step [15/62], loss: 0.4673, Accuracy: 81.25%
# epoch [12/40], step [18/62], loss: 0.5084, Accuracy: 68.75%
# epoch [12/40], step [21/62], loss: 0.4848, Accuracy: 78.12%
# epoch [12/40], step [24/62], loss: 0.3287, Accuracy: 87.50%
# epoch [12/40], step [27/62], loss: 0.4670, Accuracy: 78.12%
# epoch [12/40], step [30/62], loss: 0.5134, Accuracy: 68.75%
# epoch [12/40], step [33/62], loss: 0.5185, Accuracy: 75.00%
# epoch [12/40], step [36/62], loss: 0.7220, Accuracy: 68.75%
# epoch [12/40], step [39/62], loss: 0.4795, Accuracy: 71.88%
# epoch [12/40], step [42/62], loss: 0.6532, Accuracy: 62.50%
# epoch [12/40], step [45/62], loss: 0.6809, Accuracy: 65.62%
# epoch [12/40], step [48/62], loss: 0.4455, Accuracy: 75.00%
# epoch [12/40], step [51/62], loss: 0.3359, Accuracy: 87.50%
# epoch [12/40], step [54/62], loss: 0.3729, Accuracy: 84.38%
# epoch [12/40], step [57/62], loss: 0.3985, Accuracy: 78.12%
# epoch [12/40], step [60/62], loss: 0.4317, Accuracy: 75.00%
# Start val
# Validation #12 Accuracy 71.88 % Average Loss: 0.6990
# epoch [13/40], step [3/62], loss: 0.4065, Accuracy: 81.25%
# epoch [13/40], step [6/62], loss: 0.4072, Accuracy: 78.12%
# epoch [13/40], step [9/62], loss: 0.4930, Accuracy: 84.38%
# epoch [13/40], step [12/62], loss: 0.3217, Accuracy: 93.75%
# epoch [13/40], step [15/62], loss: 0.5376, Accuracy: 78.12%
# epoch [13/40], step [18/62], loss: 0.3386, Accuracy: 81.25%
# epoch [13/40], step [21/62], loss: 0.4676, Accuracy: 81.25%
# epoch [13/40], step [24/62], loss: 0.3371, Accuracy: 81.25%
# epoch [13/40], step [27/62], loss: 0.3807, Accuracy: 78.12%
# epoch [13/40], step [30/62], loss: 0.4452, Accuracy: 84.38%
# epoch [13/40], step [33/62], loss: 0.4850, Accuracy: 75.00%
# epoch [13/40], step [36/62], loss: 0.4455, Accuracy: 75.00%
# epoch [13/40], step [39/62], loss: 0.6374, Accuracy: 68.75%
# epoch [13/40], step [42/62], loss: 0.3738, Accuracy: 87.50%
# epoch [13/40], step [45/62], loss: 0.3524, Accuracy: 81.25%
# epoch [13/40], step [48/62], loss: 0.4139, Accuracy: 81.25%
# epoch [13/40], step [51/62], loss: 0.3542, Accuracy: 81.25%
# epoch [13/40], step [54/62], loss: 0.4299, Accuracy: 75.00%
# epoch [13/40], step [57/62], loss: 0.5595, Accuracy: 78.12%
# epoch [13/40], step [60/62], loss: 0.4677, Accuracy: 78.12%
# Start val
# Validation #13 Accuracy 75.10 % Average Loss: 0.5037
# Best Performace at epoch: 13
# save model in /content/drive/MyDrive/classification/weights/
# epoch [14/40], step [3/62], loss: 0.6377, Accuracy: 68.75%
# epoch [14/40], step [6/62], loss: 0.6312, Accuracy: 75.00%
# epoch [14/40], step [9/62], loss: 0.3717, Accuracy: 75.00%
# epoch [14/40], step [12/62], loss: 0.4220, Accuracy: 81.25%
# epoch [14/40], step [15/62], loss: 0.5074, Accuracy: 71.88%
# epoch [14/40], step [18/62], loss: 0.5720, Accuracy: 71.88%
# epoch [14/40], step [21/62], loss: 0.4831, Accuracy: 75.00%
# epoch [14/40], step [24/62], loss: 0.3809, Accuracy: 90.62%
# epoch [14/40], step [27/62], loss: 0.3842, Accuracy: 81.25%
# epoch [14/40], step [30/62], loss: 0.3335, Accuracy: 78.12%
# epoch [14/40], step [33/62], loss: 0.2358, Accuracy: 93.75%
# epoch [14/40], step [36/62], loss: 0.4607, Accuracy: 81.25%
# epoch [14/40], step [39/62], loss: 0.3200, Accuracy: 93.75%
# epoch [14/40], step [42/62], loss: 0.4617, Accuracy: 78.12%
# epoch [14/40], step [45/62], loss: 0.4591, Accuracy: 75.00%
# epoch [14/40], step [48/62], loss: 0.5345, Accuracy: 75.00%
# epoch [14/40], step [51/62], loss: 0.3809, Accuracy: 78.12%
# epoch [14/40], step [54/62], loss: 0.3289, Accuracy: 84.38%
# epoch [14/40], step [57/62], loss: 0.3398, Accuracy: 84.38%
# epoch [14/40], step [60/62], loss: 0.3647, Accuracy: 84.38%
# Start val
# Validation #14 Accuracy 73.29 % Average Loss: 0.5625
# epoch [15/40], step [3/62], loss: 0.5821, Accuracy: 62.50%
# epoch [15/40], step [6/62], loss: 0.4537, Accuracy: 78.12%
# epoch [15/40], step [9/62], loss: 0.5004, Accuracy: 81.25%
# epoch [15/40], step [12/62], loss: 0.6462, Accuracy: 71.88%
# epoch [15/40], step [15/62], loss: 0.4386, Accuracy: 71.88%
# epoch [15/40], step [18/62], loss: 0.3428, Accuracy: 84.38%
# epoch [15/40], step [21/62], loss: 0.3796, Accuracy: 81.25%
# epoch [15/40], step [24/62], loss: 0.3807, Accuracy: 84.38%
# epoch [15/40], step [27/62], loss: 0.3944, Accuracy: 75.00%
# epoch [15/40], step [30/62], loss: 0.4647, Accuracy: 84.38%
# epoch [15/40], step [33/62], loss: 0.4589, Accuracy: 78.12%
# epoch [15/40], step [36/62], loss: 0.3354, Accuracy: 87.50%
# epoch [15/40], step [39/62], loss: 0.4630, Accuracy: 78.12%
# epoch [15/40], step [42/62], loss: 0.6576, Accuracy: 68.75%
# epoch [15/40], step [45/62], loss: 0.4719, Accuracy: 87.50%
# epoch [15/40], step [48/62], loss: 0.4257, Accuracy: 81.25%
# epoch [15/40], step [51/62], loss: 0.4573, Accuracy: 81.25%
# epoch [15/40], step [54/62], loss: 0.5223, Accuracy: 71.88%
# epoch [15/40], step [57/62], loss: 0.3753, Accuracy: 87.50%
# epoch [15/40], step [60/62], loss: 0.3079, Accuracy: 87.50%
# Start val
# Validation #15 Accuracy 70.36 % Average Loss: 0.5776
# epoch [16/40], step [3/62], loss: 0.7899, Accuracy: 71.88%
# epoch [16/40], step [6/62], loss: 0.4964, Accuracy: 78.12%
# epoch [16/40], step [9/62], loss: 0.3737, Accuracy: 81.25%
# epoch [16/40], step [12/62], loss: 0.5501, Accuracy: 68.75%
# epoch [16/40], step [15/62], loss: 0.4870, Accuracy: 75.00%
# epoch [16/40], step [18/62], loss: 0.4910, Accuracy: 75.00%
# epoch [16/40], step [21/62], loss: 0.5018, Accuracy: 78.12%
# epoch [16/40], step [24/62], loss: 0.4544, Accuracy: 75.00%
# epoch [16/40], step [27/62], loss: 0.5177, Accuracy: 78.12%
# epoch [16/40], step [30/62], loss: 0.3962, Accuracy: 75.00%
# epoch [16/40], step [33/62], loss: 0.4299, Accuracy: 75.00%
# epoch [16/40], step [36/62], loss: 0.6044, Accuracy: 68.75%
# epoch [16/40], step [39/62], loss: 0.3302, Accuracy: 90.62%
# epoch [16/40], step [42/62], loss: 0.6412, Accuracy: 75.00%
# epoch [16/40], step [45/62], loss: 0.5285, Accuracy: 78.12%
# epoch [16/40], step [48/62], loss: 0.4653, Accuracy: 81.25%
# epoch [16/40], step [51/62], loss: 0.5123, Accuracy: 71.88%
# epoch [16/40], step [54/62], loss: 0.4047, Accuracy: 84.38%
# epoch [16/40], step [57/62], loss: 0.3777, Accuracy: 87.50%
# epoch [16/40], step [60/62], loss: 0.3864, Accuracy: 81.25%
# Start val
# Validation #16 Accuracy 69.46 % Average Loss: 0.6675
# epoch [17/40], step [3/62], loss: 0.7680, Accuracy: 59.38%
# epoch [17/40], step [6/62], loss: 0.4195, Accuracy: 81.25%
# epoch [17/40], step [9/62], loss: 0.4785, Accuracy: 78.12%
# epoch [17/40], step [12/62], loss: 0.4977, Accuracy: 75.00%
# epoch [17/40], step [15/62], loss: 0.6568, Accuracy: 62.50%
# epoch [17/40], step [18/62], loss: 0.3136, Accuracy: 84.38%
# epoch [17/40], step [21/62], loss: 0.2886, Accuracy: 87.50%
# epoch [17/40], step [24/62], loss: 0.4708, Accuracy: 68.75%
# epoch [17/40], step [27/62], loss: 0.4700, Accuracy: 78.12%
# epoch [17/40], step [30/62], loss: 0.3719, Accuracy: 84.38%
# epoch [17/40], step [33/62], loss: 0.6376, Accuracy: 68.75%
# epoch [17/40], step [36/62], loss: 0.4250, Accuracy: 84.38%
# epoch [17/40], step [39/62], loss: 0.3627, Accuracy: 78.12%
# epoch [17/40], step [42/62], loss: 0.5435, Accuracy: 84.38%
# epoch [17/40], step [45/62], loss: 0.5137, Accuracy: 75.00%
# epoch [17/40], step [48/62], loss: 0.2199, Accuracy: 93.75%
# epoch [17/40], step [51/62], loss: 0.8966, Accuracy: 56.25%
# epoch [17/40], step [54/62], loss: 0.4823, Accuracy: 84.38%
# epoch [17/40], step [57/62], loss: 0.5073, Accuracy: 71.88%
# epoch [17/40], step [60/62], loss: 0.5355, Accuracy: 65.62%
# Start val
# Validation #17 Accuracy 68.75 % Average Loss: 0.5898
# epoch [18/40], step [3/62], loss: 0.3644, Accuracy: 84.38%
# epoch [18/40], step [6/62], loss: 0.5223, Accuracy: 78.12%
# epoch [18/40], step [9/62], loss: 0.4764, Accuracy: 71.88%
# epoch [18/40], step [12/62], loss: 0.6165, Accuracy: 68.75%
# epoch [18/40], step [15/62], loss: 0.4082, Accuracy: 78.12%
# epoch [18/40], step [18/62], loss: 0.4195, Accuracy: 75.00%
# epoch [18/40], step [21/62], loss: 0.5206, Accuracy: 71.88%
# epoch [18/40], step [24/62], loss: 0.4420, Accuracy: 81.25%
# epoch [18/40], step [27/62], loss: 0.4663, Accuracy: 81.25%
# epoch [18/40], step [30/62], loss: 0.5191, Accuracy: 84.38%
# epoch [18/40], step [33/62], loss: 0.7158, Accuracy: 53.12%
# epoch [18/40], step [36/62], loss: 0.5477, Accuracy: 59.38%
# epoch [18/40], step [39/62], loss: 0.5007, Accuracy: 65.62%
# epoch [18/40], step [42/62], loss: 0.4875, Accuracy: 81.25%
# epoch [18/40], step [45/62], loss: 0.4208, Accuracy: 84.38%
# epoch [18/40], step [48/62], loss: 0.4269, Accuracy: 81.25%
# epoch [18/40], step [51/62], loss: 0.7818, Accuracy: 71.88%
# epoch [18/40], step [54/62], loss: 0.3043, Accuracy: 87.50%
# epoch [18/40], step [57/62], loss: 0.4224, Accuracy: 78.12%
# epoch [18/40], step [60/62], loss: 0.3887, Accuracy: 87.50%
# Start val
# Validation #18 Accuracy 74.60 % Average Loss: 0.5027
# Best Performace at epoch: 18
# save model in /content/drive/MyDrive/classification/weights/
# epoch [19/40], step [3/62], loss: 0.3468, Accuracy: 78.12%
# epoch [19/40], step [6/62], loss: 0.3120, Accuracy: 81.25%
# epoch [19/40], step [9/62], loss: 0.3095, Accuracy: 87.50%
# epoch [19/40], step [12/62], loss: 0.3968, Accuracy: 78.12%
# epoch [19/40], step [15/62], loss: 0.4363, Accuracy: 78.12%
# epoch [19/40], step [18/62], loss: 0.2177, Accuracy: 90.62%
# epoch [19/40], step [21/62], loss: 0.5569, Accuracy: 75.00%
# epoch [19/40], step [24/62], loss: 0.3220, Accuracy: 84.38%
# epoch [19/40], step [27/62], loss: 0.5009, Accuracy: 90.62%
# epoch [19/40], step [30/62], loss: 0.3443, Accuracy: 81.25%
# epoch [19/40], step [33/62], loss: 0.5505, Accuracy: 68.75%
# epoch [19/40], step [36/62], loss: 0.5346, Accuracy: 75.00%
# epoch [19/40], step [39/62], loss: 0.3415, Accuracy: 81.25%
# epoch [19/40], step [42/62], loss: 0.3726, Accuracy: 84.38%
# epoch [19/40], step [45/62], loss: 0.3890, Accuracy: 84.38%
# epoch [19/40], step [48/62], loss: 0.5433, Accuracy: 75.00%
# epoch [19/40], step [51/62], loss: 0.4834, Accuracy: 81.25%
# epoch [19/40], step [54/62], loss: 0.3603, Accuracy: 78.12%
# epoch [19/40], step [57/62], loss: 0.6231, Accuracy: 71.88%
# epoch [19/40], step [60/62], loss: 0.4204, Accuracy: 78.12%
# Start val
# Validation #19 Accuracy 75.40 % Average Loss: 0.4907
# Best Performace at epoch: 19
# save model in /content/drive/MyDrive/classification/weights/
# epoch [20/40], step [3/62], loss: 0.4246, Accuracy: 78.12%
# epoch [20/40], step [6/62], loss: 0.5100, Accuracy: 78.12%
# epoch [20/40], step [9/62], loss: 0.3653, Accuracy: 84.38%
# epoch [20/40], step [12/62], loss: 0.4552, Accuracy: 78.12%
# epoch [20/40], step [15/62], loss: 0.4488, Accuracy: 81.25%
# epoch [20/40], step [18/62], loss: 0.3910, Accuracy: 84.38%
# epoch [20/40], step [21/62], loss: 0.2902, Accuracy: 87.50%
# epoch [20/40], step [24/62], loss: 0.3125, Accuracy: 87.50%
# epoch [20/40], step [27/62], loss: 0.3983, Accuracy: 78.12%
# epoch [20/40], step [30/62], loss: 0.3611, Accuracy: 84.38%
# epoch [20/40], step [33/62], loss: 0.4599, Accuracy: 81.25%
# epoch [20/40], step [36/62], loss: 0.2464, Accuracy: 90.62%
# epoch [20/40], step [39/62], loss: 0.2623, Accuracy: 93.75%
# epoch [20/40], step [42/62], loss: 0.4934, Accuracy: 81.25%
# epoch [20/40], step [45/62], loss: 0.4105, Accuracy: 84.38%
# epoch [20/40], step [48/62], loss: 0.3849, Accuracy: 84.38%
# epoch [20/40], step [51/62], loss: 0.3153, Accuracy: 87.50%
# epoch [20/40], step [54/62], loss: 0.5451, Accuracy: 71.88%
# epoch [20/40], step [57/62], loss: 0.4057, Accuracy: 81.25%
# epoch [20/40], step [60/62], loss: 0.5349, Accuracy: 75.00%
# Start val
# Validation #20 Accuracy 70.87 % Average Loss: 0.5581
# epoch [21/40], step [3/62], loss: 0.4596, Accuracy: 84.38%
# epoch [21/40], step [6/62], loss: 0.4459, Accuracy: 71.88%
# epoch [21/40], step [9/62], loss: 0.4391, Accuracy: 71.88%
# epoch [21/40], step [12/62], loss: 0.3422, Accuracy: 84.38%
# epoch [21/40], step [15/62], loss: 0.6838, Accuracy: 68.75%
# epoch [21/40], step [18/62], loss: 0.3801, Accuracy: 81.25%
# epoch [21/40], step [21/62], loss: 0.5231, Accuracy: 71.88%
# epoch [21/40], step [24/62], loss: 0.2697, Accuracy: 87.50%
# epoch [21/40], step [27/62], loss: 0.4655, Accuracy: 75.00%
# epoch [21/40], step [30/62], loss: 0.4044, Accuracy: 81.25%
# epoch [21/40], step [33/62], loss: 0.4964, Accuracy: 84.38%
# epoch [21/40], step [36/62], loss: 0.3721, Accuracy: 71.88%
# epoch [21/40], step [39/62], loss: 0.4752, Accuracy: 81.25%
# epoch [21/40], step [42/62], loss: 0.3704, Accuracy: 81.25%
# epoch [21/40], step [45/62], loss: 0.3779, Accuracy: 84.38%
# epoch [21/40], step [48/62], loss: 0.3339, Accuracy: 87.50%
# epoch [21/40], step [51/62], loss: 0.2776, Accuracy: 87.50%
# epoch [21/40], step [54/62], loss: 0.2772, Accuracy: 84.38%
# epoch [21/40], step [57/62], loss: 0.5147, Accuracy: 78.12%
# epoch [21/40], step [60/62], loss: 0.2469, Accuracy: 90.62%
# Start val
# Validation #21 Accuracy 75.60 % Average Loss: 0.4857
# Best Performace at epoch: 21
# save model in /content/drive/MyDrive/classification/weights/
# epoch [22/40], step [3/62], loss: 0.3493, Accuracy: 84.38%
# epoch [22/40], step [6/62], loss: 0.4354, Accuracy: 78.12%
# epoch [22/40], step [9/62], loss: 0.4019, Accuracy: 84.38%
# epoch [22/40], step [12/62], loss: 0.5241, Accuracy: 75.00%
# epoch [22/40], step [15/62], loss: 0.4413, Accuracy: 78.12%
# epoch [22/40], step [18/62], loss: 0.4122, Accuracy: 75.00%
# epoch [22/40], step [21/62], loss: 0.4293, Accuracy: 81.25%
# epoch [22/40], step [24/62], loss: 0.2102, Accuracy: 90.62%
# epoch [22/40], step [27/62], loss: 0.3572, Accuracy: 81.25%
# epoch [22/40], step [30/62], loss: 0.4561, Accuracy: 78.12%
# epoch [22/40], step [33/62], loss: 0.3044, Accuracy: 93.75%
# epoch [22/40], step [36/62], loss: 0.7171, Accuracy: 59.38%
# epoch [22/40], step [39/62], loss: 0.3325, Accuracy: 84.38%
# epoch [22/40], step [42/62], loss: 0.4456, Accuracy: 75.00%
# epoch [22/40], step [45/62], loss: 0.3821, Accuracy: 78.12%
# epoch [22/40], step [48/62], loss: 0.4974, Accuracy: 68.75%
# epoch [22/40], step [51/62], loss: 0.4921, Accuracy: 71.88%
# epoch [22/40], step [54/62], loss: 0.3396, Accuracy: 90.62%
# epoch [22/40], step [57/62], loss: 0.5827, Accuracy: 71.88%
# epoch [22/40], step [60/62], loss: 0.2511, Accuracy: 93.75%
# Start val
# Validation #22 Accuracy 72.88 % Average Loss: 0.5553
# epoch [23/40], step [3/62], loss: 0.2491, Accuracy: 90.62%
# epoch [23/40], step [6/62], loss: 0.4066, Accuracy: 78.12%
# epoch [23/40], step [9/62], loss: 0.3479, Accuracy: 84.38%
# epoch [23/40], step [12/62], loss: 0.4156, Accuracy: 78.12%
# epoch [23/40], step [15/62], loss: 0.3578, Accuracy: 75.00%
# epoch [23/40], step [18/62], loss: 0.8346, Accuracy: 71.88%
# epoch [23/40], step [21/62], loss: 0.3103, Accuracy: 87.50%
# epoch [23/40], step [24/62], loss: 0.5625, Accuracy: 75.00%
# epoch [23/40], step [27/62], loss: 0.6013, Accuracy: 75.00%
# epoch [23/40], step [30/62], loss: 0.3109, Accuracy: 90.62%
# epoch [23/40], step [33/62], loss: 0.2545, Accuracy: 87.50%
# epoch [23/40], step [36/62], loss: 0.5146, Accuracy: 78.12%
# epoch [23/40], step [39/62], loss: 0.5563, Accuracy: 78.12%
# epoch [23/40], step [42/62], loss: 0.4298, Accuracy: 84.38%
# epoch [23/40], step [45/62], loss: 0.3317, Accuracy: 81.25%
# epoch [23/40], step [48/62], loss: 0.4267, Accuracy: 78.12%
# epoch [23/40], step [51/62], loss: 0.3054, Accuracy: 90.62%
# epoch [23/40], step [54/62], loss: 0.5103, Accuracy: 68.75%
# epoch [23/40], step [57/62], loss: 0.4475, Accuracy: 71.88%
# epoch [23/40], step [60/62], loss: 0.6502, Accuracy: 68.75%
# Start val
# Validation #23 Accuracy 77.32 % Average Loss: 0.4783
# Best Performace at epoch: 23
# save model in /content/drive/MyDrive/classification/weights/
# epoch [24/40], step [3/62], loss: 0.3670, Accuracy: 81.25%
# epoch [24/40], step [6/62], loss: 0.4623, Accuracy: 87.50%
# epoch [24/40], step [9/62], loss: 0.5716, Accuracy: 81.25%
# epoch [24/40], step [12/62], loss: 0.1987, Accuracy: 90.62%
# epoch [24/40], step [15/62], loss: 0.1562, Accuracy: 96.88%
# epoch [24/40], step [18/62], loss: 0.4788, Accuracy: 78.12%
# epoch [24/40], step [21/62], loss: 0.3528, Accuracy: 87.50%
# epoch [24/40], step [24/62], loss: 0.4188, Accuracy: 84.38%
# epoch [24/40], step [27/62], loss: 0.4089, Accuracy: 75.00%
# epoch [24/40], step [30/62], loss: 0.3942, Accuracy: 87.50%
# epoch [24/40], step [33/62], loss: 0.3941, Accuracy: 81.25%
# epoch [24/40], step [36/62], loss: 0.4578, Accuracy: 78.12%
# epoch [24/40], step [39/62], loss: 0.2559, Accuracy: 84.38%
# epoch [24/40], step [42/62], loss: 0.4133, Accuracy: 81.25%
# epoch [24/40], step [45/62], loss: 0.2752, Accuracy: 93.75%
# epoch [24/40], step [48/62], loss: 0.3585, Accuracy: 81.25%
# epoch [24/40], step [51/62], loss: 0.5528, Accuracy: 75.00%
# epoch [24/40], step [54/62], loss: 0.4325, Accuracy: 84.38%
# epoch [24/40], step [57/62], loss: 0.4129, Accuracy: 75.00%
# epoch [24/40], step [60/62], loss: 0.3931, Accuracy: 81.25%
# Start val
# Validation #24 Accuracy 76.31 % Average Loss: 0.5170
# epoch [25/40], step [3/62], loss: 0.2917, Accuracy: 90.62%
# epoch [25/40], step [6/62], loss: 0.2098, Accuracy: 90.62%
# epoch [25/40], step [9/62], loss: 0.3332, Accuracy: 78.12%
# epoch [25/40], step [12/62], loss: 0.2230, Accuracy: 90.62%
# epoch [25/40], step [15/62], loss: 0.3214, Accuracy: 84.38%
# epoch [25/40], step [18/62], loss: 0.5246, Accuracy: 75.00%
# epoch [25/40], step [21/62], loss: 0.2170, Accuracy: 87.50%
# epoch [25/40], step [24/62], loss: 0.2935, Accuracy: 93.75%
# epoch [25/40], step [27/62], loss: 0.3057, Accuracy: 84.38%
# epoch [25/40], step [30/62], loss: 0.2534, Accuracy: 87.50%
# epoch [25/40], step [33/62], loss: 0.3675, Accuracy: 87.50%
# epoch [25/40], step [36/62], loss: 0.3102, Accuracy: 84.38%
# epoch [25/40], step [39/62], loss: 0.4217, Accuracy: 81.25%
# epoch [25/40], step [42/62], loss: 0.3955, Accuracy: 78.12%
# epoch [25/40], step [45/62], loss: 0.3093, Accuracy: 90.62%
# epoch [25/40], step [48/62], loss: 0.4726, Accuracy: 81.25%
# epoch [25/40], step [51/62], loss: 0.3259, Accuracy: 87.50%
# epoch [25/40], step [54/62], loss: 0.4381, Accuracy: 78.12%
# epoch [25/40], step [57/62], loss: 0.3114, Accuracy: 87.50%
# epoch [25/40], step [60/62], loss: 0.4051, Accuracy: 87.50%
# Start val
# Validation #25 Accuracy 76.71 % Average Loss: 0.5584
# epoch [26/40], step [3/62], loss: 0.2648, Accuracy: 90.62%
# epoch [26/40], step [6/62], loss: 0.3099, Accuracy: 81.25%
# epoch [26/40], step [9/62], loss: 0.4125, Accuracy: 84.38%
# epoch [26/40], step [12/62], loss: 0.2777, Accuracy: 87.50%
# epoch [26/40], step [15/62], loss: 0.2710, Accuracy: 84.38%
# epoch [26/40], step [18/62], loss: 0.2508, Accuracy: 84.38%
# epoch [26/40], step [21/62], loss: 0.4974, Accuracy: 78.12%
# epoch [26/40], step [24/62], loss: 0.3044, Accuracy: 93.75%
# epoch [26/40], step [27/62], loss: 0.6681, Accuracy: 81.25%
# epoch [26/40], step [30/62], loss: 0.3301, Accuracy: 81.25%
# epoch [26/40], step [33/62], loss: 0.5121, Accuracy: 78.12%
# epoch [26/40], step [36/62], loss: 0.4917, Accuracy: 68.75%
# epoch [26/40], step [39/62], loss: 0.2778, Accuracy: 87.50%
# epoch [26/40], step [42/62], loss: 0.3848, Accuracy: 81.25%
# epoch [26/40], step [45/62], loss: 0.3610, Accuracy: 81.25%
# epoch [26/40], step [48/62], loss: 0.3466, Accuracy: 84.38%
# epoch [26/40], step [51/62], loss: 0.5441, Accuracy: 68.75%
# epoch [26/40], step [54/62], loss: 0.3292, Accuracy: 90.62%
# epoch [26/40], step [57/62], loss: 0.4944, Accuracy: 78.12%
# epoch [26/40], step [60/62], loss: 0.4075, Accuracy: 81.25%
# Start val
# Validation #26 Accuracy 75.50 % Average Loss: 0.5648
# epoch [27/40], step [3/62], loss: 0.3633, Accuracy: 90.62%
# epoch [27/40], step [6/62], loss: 0.3007, Accuracy: 81.25%
# epoch [27/40], step [9/62], loss: 0.2391, Accuracy: 90.62%
# epoch [27/40], step [12/62], loss: 0.3640, Accuracy: 87.50%
# epoch [27/40], step [15/62], loss: 0.2409, Accuracy: 90.62%
# epoch [27/40], step [18/62], loss: 0.4292, Accuracy: 81.25%
# epoch [27/40], step [21/62], loss: 0.2060, Accuracy: 93.75%
# epoch [27/40], step [24/62], loss: 0.2570, Accuracy: 87.50%
# epoch [27/40], step [27/62], loss: 0.4561, Accuracy: 65.62%
# epoch [27/40], step [30/62], loss: 0.3307, Accuracy: 81.25%
# epoch [27/40], step [33/62], loss: 0.3382, Accuracy: 84.38%
# epoch [27/40], step [36/62], loss: 0.4282, Accuracy: 78.12%
# epoch [27/40], step [39/62], loss: 0.2602, Accuracy: 87.50%
# epoch [27/40], step [42/62], loss: 0.3788, Accuracy: 78.12%
# epoch [27/40], step [45/62], loss: 0.3741, Accuracy: 81.25%
# epoch [27/40], step [48/62], loss: 0.3763, Accuracy: 81.25%
# epoch [27/40], step [51/62], loss: 0.2160, Accuracy: 90.62%
# epoch [27/40], step [54/62], loss: 0.1633, Accuracy: 96.88%
# epoch [27/40], step [57/62], loss: 0.3114, Accuracy: 81.25%
# epoch [27/40], step [60/62], loss: 0.4409, Accuracy: 75.00%
# Start val
# Validation #27 Accuracy 70.67 % Average Loss: 0.6937
# epoch [28/40], step [3/62], loss: 0.3576, Accuracy: 81.25%
# epoch [28/40], step [6/62], loss: 0.3570, Accuracy: 87.50%
# epoch [28/40], step [9/62], loss: 0.3331, Accuracy: 87.50%
# epoch [28/40], step [12/62], loss: 0.4665, Accuracy: 78.12%
# epoch [28/40], step [15/62], loss: 0.2848, Accuracy: 81.25%
# epoch [28/40], step [18/62], loss: 0.2395, Accuracy: 87.50%
# epoch [28/40], step [21/62], loss: 0.4478, Accuracy: 68.75%
# epoch [28/40], step [24/62], loss: 0.3554, Accuracy: 87.50%
# epoch [28/40], step [27/62], loss: 0.5290, Accuracy: 81.25%
# epoch [28/40], step [30/62], loss: 0.2339, Accuracy: 93.75%
# epoch [28/40], step [33/62], loss: 0.2105, Accuracy: 93.75%
# epoch [28/40], step [36/62], loss: 0.3666, Accuracy: 81.25%
# epoch [28/40], step [39/62], loss: 0.3966, Accuracy: 78.12%
# epoch [28/40], step [42/62], loss: 0.2796, Accuracy: 84.38%
# epoch [28/40], step [45/62], loss: 0.4668, Accuracy: 75.00%
# epoch [28/40], step [48/62], loss: 0.3063, Accuracy: 84.38%
# epoch [28/40], step [51/62], loss: 0.4584, Accuracy: 78.12%
# epoch [28/40], step [54/62], loss: 0.2958, Accuracy: 81.25%
# epoch [28/40], step [57/62], loss: 0.2323, Accuracy: 87.50%
# epoch [28/40], step [60/62], loss: 0.2993, Accuracy: 87.50%
# Start val
# Validation #28 Accuracy 78.43 % Average Loss: 0.6662
# epoch [29/40], step [3/62], loss: 0.2512, Accuracy: 93.75%
# epoch [29/40], step [6/62], loss: 0.3319, Accuracy: 87.50%
# epoch [29/40], step [9/62], loss: 0.5157, Accuracy: 84.38%
# epoch [29/40], step [12/62], loss: 0.3434, Accuracy: 87.50%
# epoch [29/40], step [15/62], loss: 0.4779, Accuracy: 71.88%
# epoch [29/40], step [18/62], loss: 0.3341, Accuracy: 90.62%
# epoch [29/40], step [21/62], loss: 0.3751, Accuracy: 78.12%
# epoch [29/40], step [24/62], loss: 0.4383, Accuracy: 87.50%
# epoch [29/40], step [27/62], loss: 0.5258, Accuracy: 81.25%
# epoch [29/40], step [30/62], loss: 0.3376, Accuracy: 87.50%
# epoch [29/40], step [33/62], loss: 0.2798, Accuracy: 84.38%
# epoch [29/40], step [36/62], loss: 0.3554, Accuracy: 78.12%
# epoch [29/40], step [39/62], loss: 0.2872, Accuracy: 84.38%
# epoch [29/40], step [42/62], loss: 0.2246, Accuracy: 90.62%
# epoch [29/40], step [45/62], loss: 0.3370, Accuracy: 90.62%
# epoch [29/40], step [48/62], loss: 0.1076, Accuracy: 100.00%
# epoch [29/40], step [51/62], loss: 0.2798, Accuracy: 93.75%
# epoch [29/40], step [54/62], loss: 0.6148, Accuracy: 71.88%
# epoch [29/40], step [57/62], loss: 0.4783, Accuracy: 71.88%
# epoch [29/40], step [60/62], loss: 0.4094, Accuracy: 75.00%
# Start val
# Validation #29 Accuracy 76.51 % Average Loss: 0.4675
# Best Performace at epoch: 29
# save model in /content/drive/MyDrive/classification/weights/
# epoch [30/40], step [3/62], loss: 0.3564, Accuracy: 81.25%
# epoch [30/40], step [6/62], loss: 0.2244, Accuracy: 93.75%
# epoch [30/40], step [9/62], loss: 0.2558, Accuracy: 90.62%
# epoch [30/40], step [12/62], loss: 0.2006, Accuracy: 93.75%
# epoch [30/40], step [15/62], loss: 0.2471, Accuracy: 90.62%
# epoch [30/40], step [18/62], loss: 0.2477, Accuracy: 90.62%
# epoch [30/40], step [21/62], loss: 0.3641, Accuracy: 84.38%
# epoch [30/40], step [24/62], loss: 0.4135, Accuracy: 81.25%
# epoch [30/40], step [27/62], loss: 0.3506, Accuracy: 84.38%
# epoch [30/40], step [30/62], loss: 0.3273, Accuracy: 84.38%
# epoch [30/40], step [33/62], loss: 0.1558, Accuracy: 90.62%
# epoch [30/40], step [36/62], loss: 0.2649, Accuracy: 87.50%
# epoch [30/40], step [39/62], loss: 0.3284, Accuracy: 84.38%
# epoch [30/40], step [42/62], loss: 0.3336, Accuracy: 84.38%
# epoch [30/40], step [45/62], loss: 0.4221, Accuracy: 78.12%
# epoch [30/40], step [48/62], loss: 0.2513, Accuracy: 96.88%
# epoch [30/40], step [51/62], loss: 0.4656, Accuracy: 78.12%
# epoch [30/40], step [54/62], loss: 0.4400, Accuracy: 78.12%
# epoch [30/40], step [57/62], loss: 0.3066, Accuracy: 93.75%
# epoch [30/40], step [60/62], loss: 0.5155, Accuracy: 71.88%
# Start val
# Validation #30 Accuracy 75.00 % Average Loss: 0.5434
# epoch [31/40], step [3/62], loss: 0.3487, Accuracy: 87.50%
# epoch [31/40], step [6/62], loss: 0.2959, Accuracy: 81.25%
# epoch [31/40], step [9/62], loss: 0.1812, Accuracy: 96.88%
# epoch [31/40], step [12/62], loss: 0.3516, Accuracy: 90.62%
# epoch [31/40], step [15/62], loss: 0.3185, Accuracy: 84.38%
# epoch [31/40], step [18/62], loss: 0.1806, Accuracy: 90.62%
# epoch [31/40], step [21/62], loss: 0.4554, Accuracy: 84.38%
# epoch [31/40], step [24/62], loss: 0.3911, Accuracy: 81.25%
# epoch [31/40], step [27/62], loss: 0.4500, Accuracy: 71.88%
# epoch [31/40], step [30/62], loss: 0.3284, Accuracy: 78.12%
# epoch [31/40], step [33/62], loss: 0.2622, Accuracy: 87.50%
# epoch [31/40], step [36/62], loss: 0.2539, Accuracy: 90.62%
# epoch [31/40], step [39/62], loss: 0.2217, Accuracy: 90.62%
# epoch [31/40], step [42/62], loss: 0.4244, Accuracy: 84.38%
# epoch [31/40], step [45/62], loss: 0.3945, Accuracy: 84.38%
# epoch [31/40], step [48/62], loss: 0.5176, Accuracy: 75.00%
# epoch [31/40], step [51/62], loss: 0.4012, Accuracy: 81.25%
# epoch [31/40], step [54/62], loss: 0.4314, Accuracy: 81.25%
# epoch [31/40], step [57/62], loss: 0.4265, Accuracy: 75.00%
# epoch [31/40], step [60/62], loss: 0.4123, Accuracy: 84.38%
# Start val
# Validation #31 Accuracy 77.32 % Average Loss: 0.5123
# epoch [32/40], step [3/62], loss: 0.5062, Accuracy: 75.00%
# epoch [32/40], step [6/62], loss: 0.2826, Accuracy: 84.38%
# epoch [32/40], step [9/62], loss: 0.3465, Accuracy: 87.50%
# epoch [32/40], step [12/62], loss: 0.3615, Accuracy: 84.38%
# epoch [32/40], step [15/62], loss: 0.3819, Accuracy: 84.38%
# epoch [32/40], step [18/62], loss: 0.2207, Accuracy: 90.62%
# epoch [32/40], step [21/62], loss: 0.3968, Accuracy: 78.12%
# epoch [32/40], step [24/62], loss: 0.3215, Accuracy: 87.50%
# epoch [32/40], step [27/62], loss: 0.5209, Accuracy: 78.12%
# epoch [32/40], step [30/62], loss: 0.3884, Accuracy: 81.25%
# epoch [32/40], step [33/62], loss: 0.2278, Accuracy: 90.62%
# epoch [32/40], step [36/62], loss: 0.3805, Accuracy: 87.50%
# epoch [32/40], step [39/62], loss: 0.5417, Accuracy: 71.88%
# epoch [32/40], step [42/62], loss: 0.3641, Accuracy: 81.25%
# epoch [32/40], step [45/62], loss: 0.2080, Accuracy: 96.88%
# epoch [32/40], step [48/62], loss: 0.5266, Accuracy: 78.12%
# epoch [32/40], step [51/62], loss: 0.1072, Accuracy: 96.88%
# epoch [32/40], step [54/62], loss: 0.2211, Accuracy: 90.62%
# epoch [32/40], step [57/62], loss: 0.3740, Accuracy: 81.25%
# epoch [32/40], step [60/62], loss: 0.2107, Accuracy: 90.62%
# Start val
# Validation #32 Accuracy 75.81 % Average Loss: 0.5715
# epoch [33/40], step [3/62], loss: 0.2041, Accuracy: 93.75%
# epoch [33/40], step [6/62], loss: 0.2074, Accuracy: 90.62%
# epoch [33/40], step [9/62], loss: 0.1942, Accuracy: 87.50%
# epoch [33/40], step [12/62], loss: 0.2889, Accuracy: 93.75%
# epoch [33/40], step [15/62], loss: 0.2079, Accuracy: 90.62%
# epoch [33/40], step [18/62], loss: 0.1143, Accuracy: 93.75%
# epoch [33/40], step [21/62], loss: 0.3704, Accuracy: 84.38%
# epoch [33/40], step [24/62], loss: 0.1093, Accuracy: 96.88%
# epoch [33/40], step [27/62], loss: 0.2901, Accuracy: 90.62%
# epoch [33/40], step [30/62], loss: 0.3151, Accuracy: 81.25%
# epoch [33/40], step [33/62], loss: 0.2847, Accuracy: 87.50%
# epoch [33/40], step [36/62], loss: 0.4042, Accuracy: 78.12%
# epoch [33/40], step [39/62], loss: 0.2401, Accuracy: 90.62%
# epoch [33/40], step [42/62], loss: 0.3657, Accuracy: 78.12%
# epoch [33/40], step [45/62], loss: 0.2908, Accuracy: 81.25%
# epoch [33/40], step [48/62], loss: 0.2392, Accuracy: 90.62%
# epoch [33/40], step [51/62], loss: 0.4429, Accuracy: 81.25%
# epoch [33/40], step [54/62], loss: 0.4517, Accuracy: 75.00%
# epoch [33/40], step [57/62], loss: 0.2115, Accuracy: 90.62%
# epoch [33/40], step [60/62], loss: 0.7725, Accuracy: 59.38%
# Start val
# Validation #33 Accuracy 75.00 % Average Loss: 0.4865
# epoch [34/40], step [3/62], loss: 0.3285, Accuracy: 87.50%
# epoch [34/40], step [6/62], loss: 0.5598, Accuracy: 71.88%
# epoch [34/40], step [9/62], loss: 0.3352, Accuracy: 87.50%
# epoch [34/40], step [12/62], loss: 0.2556, Accuracy: 93.75%
# epoch [34/40], step [15/62], loss: 0.3396, Accuracy: 71.88%
# epoch [34/40], step [18/62], loss: 0.3160, Accuracy: 84.38%
# epoch [34/40], step [21/62], loss: 0.2970, Accuracy: 84.38%
# epoch [34/40], step [24/62], loss: 0.1740, Accuracy: 93.75%
# epoch [34/40], step [27/62], loss: 0.2327, Accuracy: 90.62%
# epoch [34/40], step [30/62], loss: 0.2931, Accuracy: 87.50%
# epoch [34/40], step [33/62], loss: 0.0926, Accuracy: 96.88%
# epoch [34/40], step [36/62], loss: 0.5352, Accuracy: 81.25%
# epoch [34/40], step [39/62], loss: 0.4629, Accuracy: 78.12%
# epoch [34/40], step [42/62], loss: 0.3143, Accuracy: 87.50%
# epoch [34/40], step [45/62], loss: 0.6160, Accuracy: 68.75%
# epoch [34/40], step [48/62], loss: 0.2934, Accuracy: 81.25%
# epoch [34/40], step [51/62], loss: 0.2693, Accuracy: 90.62%
# epoch [34/40], step [54/62], loss: 0.3191, Accuracy: 81.25%
# epoch [34/40], step [57/62], loss: 0.2878, Accuracy: 81.25%
# epoch [34/40], step [60/62], loss: 0.6627, Accuracy: 78.12%
# Start val
# Validation #34 Accuracy 76.81 % Average Loss: 0.5372
# epoch [35/40], step [3/62], loss: 0.2668, Accuracy: 93.75%
# epoch [35/40], step [6/62], loss: 0.3143, Accuracy: 87.50%
# epoch [35/40], step [9/62], loss: 0.2003, Accuracy: 90.62%
# epoch [35/40], step [12/62], loss: 0.4177, Accuracy: 68.75%
# epoch [35/40], step [15/62], loss: 0.2274, Accuracy: 87.50%
# epoch [35/40], step [18/62], loss: 0.0935, Accuracy: 96.88%
# epoch [35/40], step [21/62], loss: 0.2488, Accuracy: 87.50%
# epoch [35/40], step [24/62], loss: 0.1630, Accuracy: 93.75%
# epoch [35/40], step [27/62], loss: 0.3198, Accuracy: 87.50%
# epoch [35/40], step [30/62], loss: 0.2091, Accuracy: 87.50%
# epoch [35/40], step [33/62], loss: 0.4874, Accuracy: 75.00%
# epoch [35/40], step [36/62], loss: 0.3471, Accuracy: 84.38%
# epoch [35/40], step [39/62], loss: 0.2999, Accuracy: 87.50%
# epoch [35/40], step [42/62], loss: 0.2542, Accuracy: 87.50%
# epoch [35/40], step [45/62], loss: 0.3478, Accuracy: 78.12%
# epoch [35/40], step [48/62], loss: 0.4005, Accuracy: 78.12%
# epoch [35/40], step [51/62], loss: 0.3478, Accuracy: 81.25%
# epoch [35/40], step [54/62], loss: 0.2950, Accuracy: 93.75%
# epoch [35/40], step [57/62], loss: 0.2727, Accuracy: 84.38%
# epoch [35/40], step [60/62], loss: 0.2715, Accuracy: 90.62%
# Start val
# Validation #35 Accuracy 73.08 % Average Loss: 0.7575
# epoch [36/40], step [3/62], loss: 0.3305, Accuracy: 81.25%
# epoch [36/40], step [6/62], loss: 0.3359, Accuracy: 87.50%
# epoch [36/40], step [9/62], loss: 0.4084, Accuracy: 81.25%
# epoch [36/40], step [12/62], loss: 0.2754, Accuracy: 90.62%
# epoch [36/40], step [15/62], loss: 0.3068, Accuracy: 75.00%
# epoch [36/40], step [18/62], loss: 0.2662, Accuracy: 87.50%
# epoch [36/40], step [21/62], loss: 0.3733, Accuracy: 87.50%
# epoch [36/40], step [24/62], loss: 0.3169, Accuracy: 81.25%
# epoch [36/40], step [27/62], loss: 0.6534, Accuracy: 75.00%
# epoch [36/40], step [30/62], loss: 0.3572, Accuracy: 78.12%
# epoch [36/40], step [33/62], loss: 0.2519, Accuracy: 84.38%
# epoch [36/40], step [36/62], loss: 0.2158, Accuracy: 93.75%
# epoch [36/40], step [39/62], loss: 0.3183, Accuracy: 87.50%
# epoch [36/40], step [42/62], loss: 0.2526, Accuracy: 93.75%
# epoch [36/40], step [45/62], loss: 0.4507, Accuracy: 81.25%
# epoch [36/40], step [48/62], loss: 0.3072, Accuracy: 84.38%
# epoch [36/40], step [51/62], loss: 0.1578, Accuracy: 96.88%
# epoch [36/40], step [54/62], loss: 0.1336, Accuracy: 100.00%
# epoch [36/40], step [57/62], loss: 0.3119, Accuracy: 78.12%
# epoch [36/40], step [60/62], loss: 0.3649, Accuracy: 87.50%
# Start val
# Validation #36 Accuracy 78.53 % Average Loss: 0.4926
# epoch [37/40], step [3/62], loss: 0.1253, Accuracy: 100.00%
# epoch [37/40], step [6/62], loss: 0.1925, Accuracy: 90.62%
# epoch [37/40], step [9/62], loss: 0.1839, Accuracy: 93.75%
# epoch [37/40], step [12/62], loss: 0.2148, Accuracy: 93.75%
# epoch [37/40], step [15/62], loss: 0.4385, Accuracy: 84.38%
# epoch [37/40], step [18/62], loss: 0.1525, Accuracy: 96.88%
# epoch [37/40], step [21/62], loss: 0.3813, Accuracy: 75.00%
# epoch [37/40], step [24/62], loss: 0.2755, Accuracy: 87.50%
# epoch [37/40], step [27/62], loss: 0.3455, Accuracy: 87.50%
# epoch [37/40], step [30/62], loss: 0.1901, Accuracy: 93.75%
# epoch [37/40], step [33/62], loss: 0.1956, Accuracy: 90.62%
# epoch [37/40], step [36/62], loss: 0.6699, Accuracy: 81.25%
# epoch [37/40], step [39/62], loss: 0.0974, Accuracy: 96.88%
# epoch [37/40], step [42/62], loss: 0.2652, Accuracy: 87.50%
# epoch [37/40], step [45/62], loss: 0.4336, Accuracy: 75.00%
# epoch [37/40], step [48/62], loss: 0.0959, Accuracy: 96.88%
# epoch [37/40], step [51/62], loss: 0.1728, Accuracy: 93.75%
# epoch [37/40], step [54/62], loss: 0.5106, Accuracy: 81.25%
# epoch [37/40], step [57/62], loss: 0.4446, Accuracy: 75.00%
# epoch [37/40], step [60/62], loss: 0.3282, Accuracy: 87.50%
# Start val
# Validation #37 Accuracy 76.71 % Average Loss: 0.5184
# epoch [38/40], step [3/62], loss: 0.2915, Accuracy: 84.38%
# epoch [38/40], step [6/62], loss: 0.3435, Accuracy: 84.38%
# epoch [38/40], step [9/62], loss: 0.3418, Accuracy: 84.38%
# epoch [38/40], step [12/62], loss: 0.1944, Accuracy: 96.88%
# epoch [38/40], step [15/62], loss: 0.2003, Accuracy: 90.62%
# epoch [38/40], step [18/62], loss: 0.1572, Accuracy: 93.75%
# epoch [38/40], step [21/62], loss: 0.3131, Accuracy: 87.50%
# epoch [38/40], step [24/62], loss: 0.3667, Accuracy: 81.25%
# epoch [38/40], step [27/62], loss: 0.2146, Accuracy: 90.62%
# epoch [38/40], step [30/62], loss: 0.2527, Accuracy: 87.50%
# epoch [38/40], step [33/62], loss: 0.3201, Accuracy: 87.50%
# epoch [38/40], step [36/62], loss: 0.4452, Accuracy: 75.00%
# epoch [38/40], step [39/62], loss: 0.1650, Accuracy: 93.75%
# epoch [38/40], step [42/62], loss: 0.4258, Accuracy: 78.12%
# epoch [38/40], step [45/62], loss: 0.2223, Accuracy: 87.50%
# epoch [38/40], step [48/62], loss: 0.2834, Accuracy: 87.50%
# epoch [38/40], step [51/62], loss: 0.1742, Accuracy: 90.62%
# epoch [38/40], step [54/62], loss: 0.1302, Accuracy: 93.75%
# epoch [38/40], step [57/62], loss: 0.4755, Accuracy: 78.12%
# epoch [38/40], step [60/62], loss: 0.3471, Accuracy: 81.25%
# Start val
# Validation #38 Accuracy 77.52 % Average Loss: 0.5787
# epoch [39/40], step [3/62], loss: 0.1567, Accuracy: 96.88%
# epoch [39/40], step [6/62], loss: 0.2732, Accuracy: 87.50%
# epoch [39/40], step [9/62], loss: 0.2633, Accuracy: 87.50%
# epoch [39/40], step [12/62], loss: 0.1692, Accuracy: 90.62%
# epoch [39/40], step [15/62], loss: 0.1874, Accuracy: 90.62%
# epoch [39/40], step [18/62], loss: 0.2078, Accuracy: 90.62%
# epoch [39/40], step [21/62], loss: 0.2408, Accuracy: 87.50%
# epoch [39/40], step [24/62], loss: 0.3376, Accuracy: 84.38%
# epoch [39/40], step [27/62], loss: 0.4661, Accuracy: 68.75%
# epoch [39/40], step [30/62], loss: 0.1853, Accuracy: 93.75%
# epoch [39/40], step [33/62], loss: 0.1902, Accuracy: 96.88%
# epoch [39/40], step [36/62], loss: 0.2347, Accuracy: 93.75%
# epoch [39/40], step [39/62], loss: 0.3038, Accuracy: 84.38%
# epoch [39/40], step [42/62], loss: 0.1651, Accuracy: 93.75%
# epoch [39/40], step [45/62], loss: 0.2434, Accuracy: 96.88%
# epoch [39/40], step [48/62], loss: 0.3405, Accuracy: 90.62%
# epoch [39/40], step [51/62], loss: 0.4378, Accuracy: 78.12%
# epoch [39/40], step [54/62], loss: 0.3373, Accuracy: 81.25%
# epoch [39/40], step [57/62], loss: 0.2592, Accuracy: 84.38%
# epoch [39/40], step [60/62], loss: 0.3348, Accuracy: 87.50%
# Start val
# Validation #39 Accuracy 74.29 % Average Loss: 0.4902
# epoch [40/40], step [3/62], loss: 0.3256, Accuracy: 87.50%
# epoch [40/40], step [6/62], loss: 0.4284, Accuracy: 81.25%
# epoch [40/40], step [9/62], loss: 0.1973, Accuracy: 93.75%
# epoch [40/40], step [12/62], loss: 0.1204, Accuracy: 96.88%
# epoch [40/40], step [15/62], loss: 0.2884, Accuracy: 90.62%
# epoch [40/40], step [18/62], loss: 0.2341, Accuracy: 87.50%
# epoch [40/40], step [21/62], loss: 0.3249, Accuracy: 84.38%
# epoch [40/40], step [24/62], loss: 0.1686, Accuracy: 87.50%
# epoch [40/40], step [27/62], loss: 0.2868, Accuracy: 84.38%
# epoch [40/40], step [30/62], loss: 0.2411, Accuracy: 93.75%
# epoch [40/40], step [33/62], loss: 0.2375, Accuracy: 87.50%
# epoch [40/40], step [36/62], loss: 0.2540, Accuracy: 84.38%
# epoch [40/40], step [39/62], loss: 0.2934, Accuracy: 81.25%
# epoch [40/40], step [42/62], loss: 0.2158, Accuracy: 90.62%
# epoch [40/40], step [45/62], loss: 0.2071, Accuracy: 87.50%
# epoch [40/40], step [48/62], loss: 0.6097, Accuracy: 87.50%
# epoch [40/40], step [51/62], loss: 0.2447, Accuracy: 90.62%
# epoch [40/40], step [54/62], loss: 0.3295, Accuracy: 90.62%
# epoch [40/40], step [57/62], loss: 0.1254, Accuracy: 96.88%
# epoch [40/40], step [60/62], loss: 0.3901, Accuracy: 81.25%
# Start val
# Validation #40 Accuracy 78.63 % Average Loss: 0.5936
